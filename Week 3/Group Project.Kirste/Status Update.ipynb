# %% [markdown]
# # Spatial Analysis of Shade Equity in Los Angeles: A Neighborhood Comparison

# %% [markdown]
# ### *To what extent does shade cover among transit stops differ across the City of Los Angeles? How do Westlake and Silverlake-Echo Park compare in terms of shade cover as well as demographic and socioeconomic characteristics?*

# %% [markdown]
# By: Jazz Henry, Max Kilman, Allison Kirste, and Nasir Sakandar

# %% [markdown]
# ## <ins> Status Update: </ins>

# %% [markdown]
# **Roles**
#
# * Team Lead on Heat Health Data: Nasir
# * Team Lead on Demographic Data: Allison
# * Team Lead on Data Visualization: Jazz
# * Team Lead on Transit Data: Max

# %% [markdown]
# **Status update**
#
# We have made progress on reworking initial individual census data exploration which will serve as a key foundation to our demographic and socioeconomic analysis in relation to shade cover and transit use. That said, we do have substantial ground to cover in preparing our overall preliminary set of findings for the midterm presentation. So far, communication between group members via email has worked fairly well, and we plan to meet again over zoom in a few days. We will need to continue coordinating the various aspects of our individual roles moving forward, so that we avoid overlap and/or gaps in our analysis and visualization processes.

# %% [markdown]
# **Data update**
#
# After receiving feedback on our initial proposal, we have revised our list of data sources. We had planned to use LA Metro Bus Stops and Bus Shade; High-resolution remote sensing data from Los Angeles Region Imagery Acquisition Consortium (LARIAC); and Census Data (ACS 1-year survey data from 2010 and 2020) - Identifying the 5 census tracts with the highest percentage of commuters by transit. Granted that the LARIAC data requires working with raster imagery (beyond the scope of UP 221), we will instead work to identify appropriate variables in the FEMA National Risk Index and Heat Health Census tracts data to serve as proxies for heat and shade. LA Street Tree Canopy data from the LA Data Hub will also serve as an additional metric and overlay for our data visualization.

# %% [markdown]
# **Concerns**
#
# <ins> Major Concerns </ins>
# * Ensuring that we conduct the analysis within the scope of what we are taught in class
# * Support for any coding guestions
#
# <ins> Minor Concerns </ins>
# * Group communications
# * Dataset download
# * Resolving Git related issues
# * Wrangling datasets and managing issues with plotly

# %% [markdown]
# **Project Overview**
#
# Extreme heat arrives without announcement. Over a span of a few hours in temperatures above 90° Fahrenheit, the limits of what the body can endure is manifested. The risk of cardiac arrest, kidney injury, and heat stroke start to increase, behavior begins to change, dehydration and mobility challenges reveal themselves. Heat does not discriminate but vulnerable populations, the elderly, the unhoused, low-income households without cooling units, and those reliant on public transportation face the brunt of the event.
#
# Urban tree cover, according to recent public health research, correlates with overall better population health as well as lower surface and air temperatures. Los Angeles’ history of racial segregation and housing discrimination has confined many low-income communities of color in denser urban areas with greater impervious surface cover and limited tree canopy cover. While many actors within these communities work to improve these conditions, public officials have yet to adequately address these inequities which structure group-differentiated life outcomes.
#
# The Westlake neighborhood is situated by the communities of Wilshire, Silverlake-Echo Park,  Central City, and south Central Los Angeles. 20% of people living in Westlake are over the age of 65 – a group at high-risk of heat streets and heat related health attributes. The median income in Westlake is $29,613, slightly above the federal poverty line for a family of four but substantially below the City of Los Angeles’ poverty line. Our preliminary analysis of American Community Survey (ACS) data reveals that Westlake has the highest percentage of transit riders of all census tracts in Los Angeles County.
#
# This project aims to conduct a broad spatial analysis of shade equity across Los Angeles County census tracts. In turn, we focus on the Westlake and (West Hollywood) neighborhoods as case studies to perform a comparative analysis of bus stop shelters and tree canopy.
#
# Our team’s interest is interdisciplinary, and we are all invested and passionate about environmental justice in the public space.

# %% [markdown]
# **Data Collection**
#
# For our project, we are collecting data from the following sources:
#
# * LA Metro Bus Stops and Bus Shade
# * FEMA National Risk Index
# * Heat Health Census tracts data
# * LA Street Tree Canopy data from the LA Data Hub
# * Census Data (ACS 1-year survey data from 2022)
#     * Identifying percentage of commuters by transit for both Westlake and Silverlake-Echo Park
#     * Evaluating income disparities between Westlake and Silverlake-Echo Park
#     * Racial makeup of Westlake vs Silverlake-Echo Park
#     * Commute type in both Westlake and Silverlake-Echo Park

# %% [markdown]
# **Methodology**
#
# Our approach to the spatial analysis of shade in Westlake and Silverlake-Echo Park is to first overlay bus stop shade data over bus stops, and then overlay tree canopy.
#
# The core of our analysis involves overlaying two key layers. First, we overlay bus stop data with the existing bus stop shade/shelter data to understand current shade coverage at each bus stop. Next, we will add a tree canopy layer. This spatially analyzes the relationship between tree canopy coverage and the shaded areas at each bus stop, highlighting where shade is insufficient. Finally, we will use Heat Health Census tracts data to understand disparities in average surface temperature. We will use census data to understand how certain populations might be affected by the shade disparities.
#
# ![Screenshot 2024-02-04 at 7.52.10 PM.png](attachment:3f959d38-d270-41d7-9c96-679e0550f259.png)

# %% [markdown]
# **What we hope to gain**
#
# We hope to enhance our technical capabilities by conducting this spatial analysis. We hope we gain a better understanding of the needs of the Westlake neighborhood, and understand shade disparities and distribution between Westlake and the relatively more affluent Silverlake-Echo Park following waves of gentrification.

# %% [markdown]
# **Sources**
#
# Vecellio, D. J., Kong, Q., Kenney, W. L., & Huber, M. (2023). Greatly enhanced risk to humans as a consequence of empirically determined lower moist heat stress tolerance. Massachusetts Institute of Technology. August 15, 2023.
#
# Ulmer JM, Wolf KL, Backman DR, Tretheway RL, Blain CJ, O'Neil-Dunne JP, Frank LD. Multiple health benefits of urban tree canopy: The mounting evidence for a green prescription. Health Place. 2016 Nov;42:54-62. doi: 10.1016/j.healthplace.2016.08.011. Epub 2016 Sep 14. PMID: 27639106. Environmental Protection Agency. (2021). Using trees and vegetation to reduce heat islands. United States Environmental Protection Agency.
#
# Eric M Wood, Sevan Esaian, Christian Benitez, Philip J Ethington, Travis Longcore, Lars Y Pomara, Historical racial redlining and contemporary patterns of income inequality negatively affect birds, their habitat, and people in Los Angeles, California, Ornithological Applications, 2023, https://doi.org/10.1093/ornithapp/duad044.
#
# [Westlake Community Plan](https://planning.lacity.gov/odocument/b189be15-6f71-43db-8a04-491fdd188729/Westlake_Community_Plan.pdf)
#
# [Westlake Demographic Profile](https://planning.lacity.gov/odocument/ca5050bc-dbe3-4a52-a859-961beb7a2da4/2017_demo_profile_westlake.pdf)
